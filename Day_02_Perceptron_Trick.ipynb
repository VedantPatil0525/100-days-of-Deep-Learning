# %%
# !git clone https://github.com/VedantPatil0525/100-days-of-Deep-Learning.git
# Out:
# Cloning into '100-days-of-Deep-Learning'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 32 (delta 6), reused 12 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (32/32), 68.95 KiB | 1.09 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# %cd 100-days-of-Deep-Learning
# Out:
# /content/100-days-of-Deep-Learning/Day_02_Perceptron_Trick/100-days-of-Deep-Learning

# %%
# !mkdir Day_02_Perceptron_Trick

# %%
# %cd Day_02_Perceptron_Trick
# Out:
# /content/100-days-of-Deep-Learning/Day_02_Perceptron_Trick/100-days-of-Deep-Learning/Day_02_Perceptron_Trick
